# %% [markdown]
# # Machine learning homework
# ## 1. Markdown, LaTeX разметка для формул
# Cущность МНК может быть выражена следующим образом:
# $$\sum_{i}e_i^2 = \sum_{i}(y_i - f_i(x))^2\to min_{x}$$

# %% [markdown]
# ## 2. Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls drive
# !ls drive/My\ Drive
# Out:
# 'My Drive'
# 'Colab Notebooks'

# %% [markdown]
# ## 3. Установить библиотеку

# %%
# !pip install pandas

# %% [markdown]
# ## 4. Выполнить несколько команд linux

# %%
# !apt install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (140 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 144487 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !tree /
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# │           │   │   │       └── dev_mmu.h
# │           │   │   ├── turing
# │           │   │   │   └── tu102
# │           │   │   │       ├── dev_fault.h
# │           │   │   │       └── dev_mmu.h
# │           │   │   └── volta
# │           │   │       └── gv100
# │           │   │           ├── dev_fault.h
# │           │   │           ├── dev_fb.h
# │           │   │           └── dev_mmu.h
# │           │   ├── nvCpuUuid.c
# │           │   ├── nvidia-uvm.Kbuild
# │           │   ├── nvidia-uvm-sources.Kbuild
# │           │   ├── nv-kthread-q.c
# │           │   ├── nv-kthread-q-selftest.c
# │           │   ├── nvstatus.c
# │           │   ├── uvm8_ampere.c
# │           │   ├── uvm8_ampere_ce.c
# │           │   ├── uvm8_ampere_fault_buffer.h
# │           │   ├── uvm8_ampere_host.c
# │           │   ├── uvm8_ampere_mmu.c
# │           │   ├── uvm8_api.h
# │           │   ├── uvm8_ats_faults.c
# ...

# %%
# !tree drive
# Out:
# drive
# └── My Drive
#     └── Colab Notebooks
#         ├── Kolesnikova_ml_hw1.ipynb
#         └── Копия блокнота "Kolesnikova_ml_hw1.ipynb"
#
# 2 directories, 2 files

# %%
# !tree sample_data
# Out:
# sample_data
# ├── anscombe.json
# ├── california_housing_test.csv
# ├── california_housing_train.csv
# ├── mnist_test.csv
# ├── mnist_train_small.csv
# └── README.md
#
# 0 directories, 6 files

# %%
# !ps -aux
# Out:
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# root           1  0.0  0.0  39196  6340 ?        Ss   13:07   0:00 /bin/bash -e
# root           8  0.3  0.7 727772 100748 ?       Sl   13:07   0:07 /tools/node/b
# root          23  0.3  0.8 423496 113900 ?       Sl   13:07   0:08 /usr/bin/pyth
# root         111  0.0  0.0  35888  4800 ?        Ss   13:07   0:00 tail -n +0 -F
# root         120  0.5  2.2 832452 305420 ?       Ssl  13:08   0:13 /usr/bin/pyth
# root         158  0.0  0.0  18376  1632 ?        S    13:08   0:00 /bin/bash --n
# root         159  0.0  0.1 2173488 16384 ?       Sl   13:08   0:00 /opt/google/d
# root         160  0.0  0.0  11596  2136 ?        S    13:08   0:00 grep --color=
# root         273  0.0  0.2 2437880 35048 ?       Sl   13:08   0:01 /opt/google/d
# root         320  0.0  0.0  18376  3024 ?        S    13:08   0:00 bash -c tail
# root         321  0.0  0.0   4568   776 ?        S    13:08   0:00 tail -n +0 -F
# ...

# %%
# !nvidia-smi
# Out:
# Mon Aug  3 13:52:58 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...
